# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/traffic_accidents_filtered.csv')
pd.crosstab(df['alignment'], df['first_crash_type']).plot(kind='bar', stacked=True)
plt.title('Crash Types by Road Alignment')
plt.ylabel('Number of Accidents')
plt.show()
